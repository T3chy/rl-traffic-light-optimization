# %%
import os
import inspect
import sys
this_folder = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
root_folder = os.path.dirname(this_folder)
sys.path.append(root_folder + '\\otm')
sys.path.append(root_folder + '\\benchmark')

# %%
import benchmark
from otm_env import *
from rl_sim import *

# %%
params = {
"cycle": 240,
"demand_arterial": 1500,
"demand_cross": [750,750],
"capacity_arterial": [2000, 2000],
"capacity_cross": [1000, 1000]
}

offset_opt = benchmark.offsetOptimizer(params)
offset_opt.optimize()
# Out:
# ([0.0, -99.42857149451333], 190.6285713264951)

# %%
env_init_info = {
    "configfile": 'network_benchmark.xml',
    "time_step": 20,
    "state_division": 7
}

bt = benchmarkTest(env_init_info)

# %%
num_steps = 300

bt.test_benchmark("initial", num_steps)
# Out:
# 100%|██████████| 6000/6000 [03:31<00:00, 28.34it/s]
# -1.6375188888889005

# %%
bt.plot_agg_queue(1, 0, "waiting", plot_signals = False)
bt.plot_agg_queue(1, 0, "waiting", start = 4000)

# %%
bt.plot_agg_queue(1, 1, "waiting", plot_signals = False)
bt.plot_agg_queue(1, 1, "waiting", start = 4000)

# %%
bt.plot_agg_queue(2, 0, "waiting", plot_signals = False)
bt.plot_agg_queue(2, 0, "waiting", start = 4000)

# %%
bt.plot_agg_queue(2, 1, "waiting", plot_signals = False)
bt.plot_agg_queue(2, 1, "waiting", start = 4000)
